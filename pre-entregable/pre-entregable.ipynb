# %%
# API https://api.nasa.gov/
import pandas as pd
import requests
from datetime import datetime, timedelta
# Out:
# /tmp/ipykernel_5613/928833.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
API_KEY = 'WnvDv550SuYfAfP9V9eqiWGpn4obrthY21pxgmES'
DAYS_TO_SUBTRACT = 7
TODAY = datetime.now().strftime('%Y-%m-%d')
START_TIME = datetime.now() - .strftime('%Y-%m-%d')
URL = 'https://api.nasa.gov/neo/rest/v1/feed?start_date=' + TODAY + '&end_date=' + TODAY + '&api_key=' + API_KEY

# %%
response = requests.get(URL).json()
df = pd.DataFrame(response['near_earth_objects'][TODAY])
df.head(1)
# Out:
#                                                links       id  \
# 0  {'self': 'http://api.nasa.gov/neo/rest/v1/neo/...  2448818
#
#   neo_reference_id                name  \
# 0          2448818  448818 (2011 UU20)
#
#                                         nasa_jpl_url  absolute_magnitude_h  \
# 0  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 17.81
#
#                                   estimated_diameter  \
# 0  {'kilometers': {'estimated_diameter_min': 0.72...
#
#    is_potentially_hazardous_asteroid  \
# 0                              False
#
#                                  close_approach_data  is_sentry_object
# 0  [{'close_approach_date': '2024-03-02', 'close_...             False

# %%
filtered_df = df[["id", "name", "absolute_magnitude_h", "estimated_diameter", "is_potentially_hazardous_asteroid", "is_sentry_object"]]
filtered_df
# Out:
#           id                name  absolute_magnitude_h  \
# 0    2448818  448818 (2011 UU20)                 17.81
# 1    2539856   539856 (2017 EV2)                 20.92
# 2    3071939         (2001 BB16)                 23.20
# 3    3069758         (2001 CP36)                 23.92
# 4    3160748        (2003 SW130)                 29.10
# 5    3289172         (2005 QP87)                 27.70
# 6    3556127         (2011 BQ50)                 28.00
# 7    3674864          (2014 OG1)                 21.72
# 8    3693428           (2014 UR)                 26.60
# 9   54117581          (2021 CM7)                 21.10
# 10  54184281          (2021 PC7)                 19.39
# 11  54200470          (2021 SD3)                 25.12
# 12  54426894          (2024 CX6)                 23.67
# 13  54427300           (2024 DF)                 24.42
#
#                                    estimated_diameter  \
# 0   {'kilometers': {'estimated_diameter_min': 0.72...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 filtered_df["estimated_diameter": ["kilometers"]]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4073, in DataFrame.__getitem__(self, key)
#    4071 # Do we have a slicer (on rows)?
#    4072 if isinstance(key, slice):
# -> 4073     return self._getitem_slice(key)
#    4075 # Do we have a (boolean) DataFrame?
#    4076 if isinstance(key, DataFrame):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:4343, in NDFrame._getitem_slice(self, key)
#    4338 """
#    4339 __getitem__ for the case where the key is a slice object.
#    4340 """
#    4341 # _convert_slice_indexer to determine if this slice is positional
#    4342 #  or label based, and if the latter, convert to positional
# -> 4343 slobj = self.index._convert_slice_indexer(key, kind="getitem")
# ...
